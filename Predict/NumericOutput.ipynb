# %%
import pandas as pd

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
test.head()
# Out:
#      id                              belongs_to_collection   budget  \
# 0  3001  [{'id': 34055, 'name': 'Pokémon Collection', '...        0
# 1  3002                                                NaN    88000
# 2  3003                                                NaN        0
# 3  3004                                                NaN  6800000
# 4  3005                                                NaN  2000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 4  [{'id': 36, 'name': 'History'}, {'id': 99, 'na...
#
#                                             homepage    imdb_id  \
# 0  http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                NaN  tt0051380
# ...

# %%
import pandas as pd

# Load train.csv
train = pd.read_csv('train.csv')

# Select relevant columns for training
selected_columns = ['budget', 'revenue']
train_data = train[selected_columns].dropna()

# Define a simple mean squared error function
def mean_squared_error(y):
    mean_value = y.mean()
    mse = ((y - mean_value) ** 2).mean()
    return mse

# Define a function to recursively construct a decision tree
def decision_tree_regression(X, y):
    # If all target values are the same, return a leaf node with the mean value
    if y.nunique() == 1:
        return {'value': y.mean()}

    # If all features are the same, return a leaf node with the mean value
    if X.drop_duplicates().shape[0] == 1:
        return {'value': y.mean()}

    # Find the best feature and threshold to split the data
    best_feature, best_threshold = find_best_split(X, y)

    # Split the data based on the best feature and threshold
    left_mask = X[best_feature] <= best_threshold
    right_mask = ~left_mask

    # Recursively build the left and right subtrees
    left_tree = decision_tree_regression(X[left_mask], y[left_mask])
    right_tree = decision_tree_regression(X[right_mask], y[right_mask])

    # Return the decision tree node
    return {'feature': best_feature, 'threshold': best_threshold, 'left': left_tree, 'right': right_tree}

# Define a function to find the best split for a given feature
def find_best_split(X, y):
    best_feature = None
    best_threshold = None
    best_mse = float('inf')

    # Loop through each unique value of each feature
    for feature in X.columns:
        for threshold in X[feature].unique():
            left_mask = X[feature] <= threshold
            right_mask = ~left_mask

            left_mse = mean_squared_error(y[left_mask])
            right_mse = mean_squared_error(y[right_mask])

            total_mse = left_mse + right_mse

            # Update best split if the current split is better
            if total_mse < best_mse:
                best_mse = total_mse
                best_feature = feature
                best_threshold = threshold

    return best_feature, best_threshold

# Define a function to make predictions using the decision tree
def predict(tree, X):
    if 'value' in tree:  # Leaf node
        return tree['value']

    if X[tree['feature']] <= tree['threshold']:
        return predict(tree['left'], X)
    else:
        return predict(tree['right'], X)

# Train the decision tree
X_train = train_data[['budget']]
y_train = train_data['revenue']
tree = decision_tree_regression(X_train, y_train)

# Apply the decision tree to the test.csv data
test = pd.read_csv('test.csv')
test['predicted_revenue'] = test.apply(lambda row: predict(tree, row), axis=1)

# Print the first few rows of the test data with predicted revenue
print(test[['id', 'budget', 'predicted_revenue']])
# Out:
#         id    budget  predicted_revenue
# 0     3001         0       1.218701e+07
# 1     3002     88000       5.000000e+06
# 2     3003         0       1.218701e+07
# 3     3004   6800000       1.070323e+07
# 4     3005   2000000       9.285284e+06
# ...    ...       ...                ...
# 4393  7394  42000000       1.230191e+08
# 4394  7395  19000000       6.778309e+07
# 4395  7396  16000000       3.366959e+07
# 4396  7397   2000000       9.285284e+06
# 4397  7398     64000       4.164980e+05
#
# [4398 rows x 3 columns]
